# %%
# respected sir/madam
# Name    : K.MANI JHANESWAR 
# Email    : smartmani437@gmail.com
# BATCH : data science january batch
# Studying at PARUL UNIVERSITY

#                      MAJOR PROJECT - BILLIONAIRES STATISTICS

# %%
#Here i am going to importing whatever modules and packages neccesary to built my project 
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as pp
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#here i am loading my dataset which is in CSV type with help of PANDAS 

data=pd.read_csv(r"C:\Users\mani jhaneswar\Desktop\INTERNSHIP\Billionaires Statistics Dataset for MAJOR PROJECT.csv")

# %%
#ANALYSIS OF DATASET
data.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
data.tail()
# Out:
#       rank  finalWorth         category              personName   age  \
# 2635  2540        1000       Healthcare                 Yu Rong  51.0
# 2636  2540        1000  Food & Beverage  Richard Yuengling, Jr.  80.0
# 2637  2540        1000    Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000      Real Estate  Zhang Guiping & family  71.0
# 2639  2540        1000      Diversified             Inigo Zobel  66.0
#
#             country        city                        source  \
# 2635          China    Shanghai                Health clinics
# 2636  United States  Pottsville                          Beer
# 2637          China       Gaomi  Tyre manufacturing machinery
# 2638          China     Nanjing                   Real estate
# 2639    Philippines      Makati                   Diversified
#
#            industries countryOfCitizenship  ... cpi_change_country  \
# 2635       Healthcare                China  ...                2.9
# ...

# %%
data.shape
# Out:
# (2640, 35)

# %% [markdown]
# # PREPROCESSING :

# %%
data.columns
# Out:
# Index(['rank', 'finalWorth', 'category', 'personName', 'age', 'country',
#        'city', 'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName',
#        'title', 'date', 'state', 'residenceStateRegion', 'birthYear',
#        'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',
#        'gdp_country', 'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
data.describe()
# Out:
#           finalWorth          age    birthYear   birthMonth     birthDay  \
# count    2640.000000  2575.000000  2564.000000  2564.000000  2564.000000
# mean     4623.787879    65.140194  1957.183307     5.740250    12.099844
# std      9834.240939    13.258098    13.282516     3.710085     9.918876
# min      1000.000000    18.000000  1921.000000     1.000000     1.000000
# 25%      1500.000000    56.000000  1948.000000     2.000000     1.000000
# 50%      2300.000000    65.000000  1957.000000     6.000000    11.000000
# 75%      4200.000000    75.000000  1966.000000     9.000000    21.000000
# max    211000.000000   101.000000  2004.000000    12.000000    31.000000
#
#        cpi_country  cpi_change_country  gross_tertiary_education_enrollment  \
# count  2456.000000         2456.000000                          2458.000000
# mean    127.755204            4.364169                            67.225671
# std      26.452951            3.623763                            21.343426
# ...

# %%
data.isnull()
# Out:
#        rank  finalWorth  category  personName    age  country   city  source  \
# 0     False       False     False       False  False    False  False   False
# 1     False       False     False       False  False    False  False   False
# 2     False       False     False       False  False    False  False   False
# 3     False       False     False       False  False    False  False   False
# 4     False       False     False       False  False    False  False   False
# ...     ...         ...       ...         ...    ...      ...    ...     ...
# 2635  False       False     False       False  False    False  False   False
# 2636  False       False     False       False  False    False  False   False
# 2637  False       False     False       False  False    False  False   False
# 2638  False       False     False       False  False    False  False   False
# 2639  False       False     False       False  False    False  False   False
#
# ...

# %%
data.columns
# Out:
# Index(['finalWorth', 'category', 'personName', 'age', 'country', 'city',
#        'industries', 'countryOfCitizenship', 'organization', 'selfMade',
#        'status', 'gender', 'birthDate', 'lastName', 'firstName', 'title',
#        'date', 'state', 'residenceStateRegion', 'birthYear', 'birthMonth',
#        'birthDay', 'cpi_country', 'cpi_change_country', 'gdp_country',
#        'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %% [markdown]
# # RELATING VARIABLES WITH SCATTER PLOTS

# %%
#here i am relating dependent and independent variables which are valuable insights 
#considering AGE is independent variable and FIANLWORTH is dependent variable
#ploting age variable on x-axis and finalworth variable on y-axis

sb.relplot(x="age",y="finalWorth",data=data)
# Out:
# C:\Users\mani jhaneswar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#here i am ploting source and finalworth as independent and dependent variables 

sb.relplot(x="source",y="finalWorth",kind='line',data=data)
# Out:
# C:\Users\mani jhaneswar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # CREATING LINEAR REGRESSION - train and test model

# %%
#model the dataset with help of linear Regression 
#starting with train and test model the data

new_data=data[['age','finalWorth']]
new_data
# Out:
#        age  finalWorth
# 0     74.0      211000
# 1     51.0      180000
# 2     59.0      114000
# 3     78.0      107000
# 4     92.0      106000
# ...    ...         ...
# 2635  51.0        1000
# 2636  80.0        1000
# 2637  60.0        1000
# 2638  71.0        1000
# 2639  66.0        1000
#
# [2640 rows x 2 columns]

# %%
#data visualization of age and fianlworth with help of ploting graph kind of Line 

new_data.plot(x='age',y='finalWorth',kind='line')
# Out:
# <Axes: xlabel='age'>

# %%
data.plot(x='source',y='finalWorth',kind='scatter')
# Out:
# <Axes: xlabel='source', ylabel='finalWorth'>

# %%
#data analysis of age and final worth of each billionaire 

X=data[['age']]
y=data['finalWorth']
X.shape,y.shape
# Out:
# ((2640, 1), (2640,))

# %%
#modeling the data into train and test model 
#that means 20 percent of test and 80 percent of train 

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print("X_TRAIN : ",x_train.shape)
print("X_TEST : ",X_test.shape)
print("Y-TRAIN : ",y_train.shape)
print("Y_TEST : ",y_test.shape)
# Out:
# X_TRAIN :  (2112, 1)
# X_TEST :  (528, 1)
# Y-TRAIN :  (2112,)
# Y_TEST :  (528,)

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Training the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Making predictions
predictions = rf_model.predict(X_test)

# Calculating the accuracy of the model
accuracy = accuracy_score(y_test, predictions)
print("Accuracy of the Random Forest model:", accuracy)
# Out:
# Accuracy of the Random Forest model: 0.028409090909090908

# %%
#model fitting of data and linaer regression

imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=0)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#data model prediction for valueable insights from age and finalworth 

y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (528,)

# %%
#model evaluation and performance of linear regression model using metrics like Mean Squared Error (MSE), R-squared, or Root Mean Squared Error (RMSE) to assess how well the model fits the data.

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

#here i taken R2:variance of the dependent variable target explained by the independent variables 

r2=r2_score(y_test,y_pred)

#MSE: avearge score distance between the predicted and actual values

mse=mean_squared_error(y_test,y_pred)

#MAE: avearge absolute distance between the predicted and actual values 

mae=mean_absolute_error(y_test,y_pred)

#INTERCEPT :starting point of regression line on the y-axis

intercept=model.intercept_

print("R2 SCORE : ",r2)
print("MEAN SQUARED ERROR : ",mse)
print("MEAN ABSOLUTE ERROR : ",mae)
print("INTERCEPT : ",intercept)
# Out:
# R2 SCORE :  0.01055596350743715
# MEAN SQUARED ERROR :  75415324.48212963
# MEAN ABSOLUTE ERROR :  3721.971258924456
# INTERCEPT :  1847.31477285137

# %%
#I am going to plotting predicted vs actual values 
#predicted values on x-axis and actual values on y-axis 

pp.scatter(y_test,y_pred)
pp.plot([y.min(),y.max()],[y.min(),y.max()],color='red')

pp.xlabel('ACTUAL VALUES')
pp.ylabel('PREDICTED VALUES')
pp.title('PREDICTED VS ACTUAL VALUES {LINEAR REGRESSION}')
pp.show()

# %%
sb.regplot(x=y_test,y=y_pred,ci=None,color='black')
# Out:
# <Axes: xlabel='finalWorth'>

# %% [markdown]
# # RECOMMENDATIONS :
# Recommendations for a data science project analyzing the Billionaires Dataset using linear regression can be explore the creation of new features or variables that could enhance the predictive power of the model, such as combining existing variables or extracting new information from the data.
# Explore ensemble methods like Random Forest or Gradient Boosting to combine multiple models for improved predictive accuracy and stability.
# Focus on enhancing the interpretability of the model by analyzing feature importance and understanding how each variable contributes to predicting billionaires' final worth.

# %% [markdown]
# # CONCLUSION :

# %% [markdown]
# In conclusion, the Billionaires Dataset data science project has provided valuable insights into the relationship between billionaires age and their final worth. Through the application of linear regression analysis, key findings have been uncovered, shedding light on how age influences the wealth of billionaires.
#
# This data science project has not only provided valuable insights into the relationship between age and wealth among billionaires but has also laid the foundation for future research endeavors that can delve deeper into the complexities of billionaire wealth generation and distribution.

# %% [markdown]
# # THANK YOU

# %% [markdown]
# # K.MANI JHANESWAR
# # smartmani437@gmail.com
# # STUDYING AT PARUL UNIVERSITY
